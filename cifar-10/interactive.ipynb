# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import os
import tensorflow as tf
import tensorflow_data_validation as tfdv
import tensorflow_model_analysis as tfma
import tempfile
from tfx.components.evaluator.component import Evaluator
from tfx.components.example_gen.import_example_gen.component import ImportExampleGen
from tfx.components.example_validator.component import ExampleValidator
from tfx.components.model_validator.component import ModelValidator
from tfx.components.pusher.component import Pusher
from tfx.components.schema_gen.component import SchemaGen
from tfx.components.statistics_gen.component import StatisticsGen
from tfx.components.trainer.component import Trainer
from tfx.components.transform.component import Transform
from tfx.orchestration.interactive.interactive_context import InteractiveContext
from tfx.proto import example_gen_pb2
from tfx.proto import evaluator_pb2
from tfx.proto import pusher_pb2
from tfx.proto import trainer_pb2
from tfx.utils.dsl_utils import external_input
from tfx.utils.types import get_split_uri
# Out:
# WARNING:tensorflow:From /home/ummon/Documents/github.com/valeriano-manassero/tfx-kubeflow-pipelines/venv/lib/python3.6/site-packages/tfx/components/transform/executor.py:57: The name tf.FixedLenFeature is deprecated. Please use tf.io.FixedLenFeature instead.
#
# WARNING:tensorflow:From /home/ummon/Documents/github.com/valeriano-manassero/tfx-kubeflow-pipelines/venv/lib/python3.6/site-packages/tfx/components/transform/executor.py:57: from_feature_spec (from tensorflow_transform.tf_metadata.dataset_schema) is deprecated and will be removed in a future version.
# Instructions for updating:
# from_feature_spec is a deprecated, use schema_utils.schema_from_feature_spec

# %%
tf.enable_eager_execution()

# %%
_root = '.'
_data_root = _root + '/data'
_serving_model_dir = os.path.join(tempfile.mkdtemp(),'serving_model/cifar-10')

# %%
context = InteractiveContext()

# %%
input_split = example_gen_pb2.Input(splits=[
    example_gen_pb2.Input.Split(name='train', pattern='train.tfrecord'),
    example_gen_pb2.Input.Split(name='eval', pattern='test.tfrecord')
])
examples = external_input(_data_root)
example_gen = ImportExampleGen(input_base=examples, input_config=input_split)

context.run(example_gen)
# Out:
# WARNING:tensorflow:From /home/ummon/Documents/github.com/valeriano-manassero/tfx-kubeflow-pipelines/venv/lib/python3.6/site-packages/tfx/orchestration/component_launcher.py:87: The name tf.logging.info is deprecated. Please use tf.compat.v1.logging.info instead.
#
# INFO:tensorflow:Run driver for ImportExampleGen
# INFO:tensorflow:Created run context interactive-2019-09-10T08_41_53.263965.2019-09-10T08:41:55.852685.
# INFO:tensorflow:ID of run context interactive-2019-09-10T08_41_53.263965.2019-09-10T08:41:55.852685 is 1.
# INFO:tensorflow:Processing input ./data.
# INFO:tensorflow:single_input Artifact(type_name: ExternalPath, uri: ./data, split: , id: 0).
# INFO:tensorflow:single_input.artifact uri: "./data"
# properties {
#   key: "split"
#   value {
#     string_value: ""
#   }
# }
# properties {
#   key: "type_name"
#   value {
#     string_value: "ExternalPath"
#   }
# }
# .
# INFO:tensorflow:Registered new input: id: 1
# type_id: 2
# uri: "./data"
# properties {
#   key: "split"
#   value {
#     string_value: ""
#   }
# }
# properties {
#   key: "state"
#   value {
#     string_value: "published"
#   }
# }
# properties {
#   key: "type_name"
#   value {
#     string_value: "ExternalPath"
#   }
# }
# custom_properties {
#   key: "input_fingerprint"
#   value {
#     string_value: "split:train,num_files:1,total_bytes:67847507,xor_checksum:1567502741,sum_checksum:1567502741\nsplit:eval,num_files:1,total_bytes:13573009,xor_checksum:1567502749,sum_checksum:1567502749"
#   }
# }
#
# WARNING:tensorflow:From /home/ummon/Documents/github.com/valeriano-manassero/tfx-kubeflow-pipelines/venv/lib/python3.6/site-packages/tfx/components/base/base_driver.py:44: The name tf.gfile.Exists is deprecated. Please use tf.io.gfile.exists instead.
#
# INFO:tensorflow:Resolved input artifacts are: {'input_base': [Artifact(type_name: ExternalPath, uri: ./data, split: , id: 1)]}
# INFO:tensorflow:Prepared EXECUTION:
#  type_id: 3
# properties {
#   key: "component_id"
#   value {
#     string_value: "ImportExampleGen"
#   }
# }
# properties {
#   key: "custom_config"
#   value {
#     string_value: "None"
#   }
# }
# properties {
#   key: "input_config"
#   value {
#     string_value: "{\n  \"splits\": [\n    {\n      \"name\": \"train\",\n      \"pattern\": \"train.tfrecord\"\n    },\n    {\n      \"name\": \"eval\",\n      \"pattern\": \"test.tfrecord\"\n    }\n  ]\n}"
#   }
# }
# properties {
#   key: "output_config"
#   value {
#     string_value: "{}"
#   }
# }
# properties {
#   key: "pipeline_name"
#   value {
#     string_value: "interactive-2019-09-10T08_41_53.263965"
#   }
# }
# properties {
#   key: "pipeline_root"
#   value {
#     string_value: "/tmp/tfx-interactive-2019-09-10T08_41_53.263965-6bkpvtgc"
#   }
# }
# properties {
#   key: "run_id"
#   value {
#     string_value: "2019-09-10T08:41:55.852685"
#   }
# }
# properties {
#   key: "state"
#   value {
#     string_value: "new"
#   }
# }
#
# INFO:tensorflow:Execution id of the upcoming component execution is 1
# INFO:tensorflow:Checking previous run for execution_type_name tfx.components.example_gen.import_example_gen.component.ImportExampleGen and input_artifacts {'input_base': [Artifact(type_name: ExternalPath, uri: ./data, split: , id: 1)]}
# INFO:tensorflow:Prepared EXECUTION:
#  type_id: 3
# properties {
#   key: "component_id"
#   value {
#     string_value: "ImportExampleGen"
#   }
# }
# properties {
#   key: "custom_config"
#   value {
#     string_value: "None"
#   }
# }
# properties {
#   key: "input_config"
#   value {
#     string_value: "{\n  \"splits\": [\n    {\n      \"name\": \"train\",\n      \"pattern\": \"train.tfrecord\"\n    },\n    {\n      \"name\": \"eval\",\n      \"pattern\": \"test.tfrecord\"\n    }\n  ]\n}"
#   }
# }
# properties {
#   key: "output_config"
#   value {
#     string_value: "{}"
#   }
# }
# properties {
#   key: "pipeline_name"
#   value {
#     string_value: "interactive-2019-09-10T08_41_53.263965"
#   }
# }
# properties {
#   key: "pipeline_root"
#   value {
#     string_value: "/tmp/tfx-interactive-2019-09-10T08_41_53.263965-6bkpvtgc"
#   }
# }
# properties {
#   key: "run_id"
#   value {
#     string_value: "2019-09-10T08:41:55.852685"
#   }
# }
# properties {
#   key: "state"
#   value {
#     string_value: "complete"
#   }
# }
#
# INFO:tensorflow:No execution matching type id and input artifacts found
# INFO:tensorflow:Cached results not found, move on to new execution
# INFO:tensorflow:Creating output artifact uri /tmp/tfx-interactive-2019-09-10T08_41_53.263965-6bkpvtgc/ImportExampleGen/examples/1/train/ as directory
# INFO:tensorflow:Creating output artifact uri /tmp/tfx-interactive-2019-09-10T08_41_53.263965-6bkpvtgc/ImportExampleGen/examples/1/eval/ as directory
# INFO:tensorflow:Output artifacts skeleton for the upcoming execution are: {'examples': [Artifact(type_name: ExamplesPath, uri: /tmp/tfx-interactive-2019-09-10T08_41_53.263965-6bkpvtgc/ImportExampleGen/examples/1/train/, split: train, id: 0), Artifact(type_name: ExamplesPath, uri: /tmp/tfx-interactive-2019-09-10T08_41_53.263965-6bkpvtgc/ImportExampleGen/examples/1/eval/, split: eval, id: 0)]}
# INFO:tensorflow:Execution properties for the upcoming execution are: {'input_config': '{\n  "splits": [\n    {\n      "name": "train",\n      "pattern": "train.tfrecord"\n    },\n    {\n      "name": "eval",\n      "pattern": "test.tfrecord"\n    }\n  ]\n}', 'output_config': '{}', 'custom_config': None}
# INFO:tensorflow:Run executor for ImportExampleGen
# INFO:tensorflow:Starting Executor execution.
# INFO:tensorflow:Inputs for Executor is: {"input_base": [{"artifact": {"id": "1", "typeId": "2", "uri": "./data", "properties": {"state": {"stringValue": "published"}, "type_name": {"stringValue": "ExternalPath"}, "split": {"stringValue": ""}}, "customProperties": {"input_fingerprint": {"stringValue": "split:train,num_files:1,total_bytes:67847507,xor_checksum:1567502741,sum_checksum:1567502741\nsplit:eval,num_files:1,total_bytes:13573009,xor_checksum:1567502749,sum_checksum:1567502749"}}}, "artifact_type": {"id": "2", "name": "ExternalPath", "properties": {"name": "STRING", "type_name": "STRING", "state": "STRING", "producer_component": "STRING", "span": "INT", "pipeline_name": "STRING", "split": "STRING"}}}]}
# INFO:tensorflow:Outputs for Executor is: {"examples": [{"artifact": {"uri": "/tmp/tfx-interactive-2019-09-10T08_41_53.263965-6bkpvtgc/ImportExampleGen/examples/1/train/", "properties": {"name": {"stringValue": "examples"}, "type_name": {"stringValue": "ExamplesPath"}, "split": {"stringValue": "train"}, "producer_component": {"stringValue": "ImportExampleGen"}, "pipeline_name": {"stringValue": "interactive-2019-09-10T08_41_53.263965"}}}, "artifact_type": {"name": "ExamplesPath", "properties": {"state": "STRING", "producer_component": "STRING", "span": "INT", "pipeline_name": "STRING", "split": "STRING", "name": "STRING", "type_name": "STRING"}}}, {"artifact": {"uri": "/tmp/tfx-interactive-2019-09-10T08_41_53.263965-6bkpvtgc/ImportExampleGen/examples/1/eval/", "properties": {"name": {"stringValue": "examples"}, "type_name": {"stringValue": "ExamplesPath"}, "split": {"stringValue": "eval"}, "producer_component": {"stringValue": "ImportExampleGen"}, "pipeline_name": {"stringValue": "interactive-2019-09-10T08_41_53.263965"}}}, "artifact_type": {"name": "ExamplesPath", "properties": {"split": "STRING", "name": "STRING", "type_name": "STRING", "state": "STRING", "producer_component": "STRING", "span": "INT", "pipeline_name": "STRING"}}}]}
# INFO:tensorflow:Execution properties for Executor is: {"input_config": "{\n  \"splits\": [\n    {\n      \"name\": \"train\",\n      \"pattern\": \"train.tfrecord\"\n    },\n    {\n      \"name\": \"eval\",\n      \"pattern\": \"test.tfrecord\"\n    }\n  ]\n}", "output_config": "{}", "custom_config": null}
# INFO:tensorflow:Generating examples.
# INFO:tensorflow:Reading input TFExample data ./data/train.tfrecord.
# INFO:tensorflow:Reading input TFExample data ./data/test.tfrecord.
# INFO:tensorflow:Examples generated.
# INFO:tensorflow:Run publisher for ImportExampleGen
# INFO:tensorflow:Whether cached results are used: False
# INFO:tensorflow:Execution id: 1
# INFO:tensorflow:Inputs: {'input_base': [Artifact(type_name: ExternalPath, uri: ./data, split: , id: 1)]}
# INFO:tensorflow:Outputs: {'examples': [Artifact(type_name: ExamplesPath, uri: /tmp/tfx-interactive-2019-09-10T08_41_53.263965-6bkpvtgc/ImportExampleGen/examples/1/train/, split: train, id: 0), Artifact(type_name: ExamplesPath, uri: /tmp/tfx-interactive-2019-09-10T08_41_53.263965-6bkpvtgc/ImportExampleGen/examples/1/eval/, split: eval, id: 0)]}
# INFO:tensorflow:Publishing execution id: 1
# type_id: 3
# properties {
#   key: "component_id"
#   value {
#     string_value: "ImportExampleGen"
#   }
# }
# properties {
#   key: "custom_config"
#   value {
#     string_value: "None"
#   }
# }
# properties {
#   key: "input_config"
#   value {
#     string_value: "{\n  \"splits\": [\n    {\n      \"name\": \"train\",\n      \"pattern\": \"train.tfrecord\"\n    },\n    {\n      \"name\": \"eval\",\n      \"pattern\": \"test.tfrecord\"\n    }\n  ]\n}"
#   }
# }
# properties {
#   key: "output_config"
#   value {
#     string_value: "{}"
#   }
# }
# properties {
#   key: "pipeline_name"
#   value {
#     string_value: "interactive-2019-09-10T08_41_53.263965"
#   }
# }
# properties {
#   key: "pipeline_root"
#   value {
#     string_value: "/tmp/tfx-interactive-2019-09-10T08_41_53.263965-6bkpvtgc"
#   }
# }
# properties {
#   key: "run_id"
#   value {
#     string_value: "2019-09-10T08:41:55.852685"
#   }
# }
# properties {
#   key: "state"
#   value {
#     string_value: "complete"
#   }
# }
# , with inputs {'input_base': [Artifact(type_name: ExternalPath, uri: ./data, split: , id: 1)]} and outputs {'examples': [Artifact(type_name: ExamplesPath, uri: /tmp/tfx-interactive-2019-09-10T08_41_53.263965-6bkpvtgc/ImportExampleGen/examples/1/train/, split: train, id: 0), Artifact(type_name: ExamplesPath, uri: /tmp/tfx-interactive-2019-09-10T08_41_53.263965-6bkpvtgc/ImportExampleGen/examples/1/eval/, split: eval, id: 0)]}
# INFO:tensorflow:Published execution with final outputs {'examples': [Artifact(type_name: ExamplesPath, uri: /tmp/tfx-interactive-2019-09-10T08_41_53.263965-6bkpvtgc/ImportExampleGen/examples/1/train/, split: train, id: 2), Artifact(type_name: ExamplesPath, uri: /tmp/tfx-interactive-2019-09-10T08_41_53.263965-6bkpvtgc/ImportExampleGen/examples/1/eval/, split: eval, id: 3)]}
# WARNING:tensorflow:From /home/ummon/Documents/github.com/valeriano-manassero/tfx-kubeflow-pipelines/venv/lib/python3.6/site-packages/tfx/orchestration/component_launcher.py:87: The name tf.logging.info is deprecated. Please use tf.compat.v1.logging.info instead.
#
# INFO:tensorflow:Run driver for ImportExampleGen
# INFO:tensorflow:Created run context interactive-2019-09-10T08_41_53.263965.2019-09-10T08:41:55.852685.
# INFO:tensorflow:ID of run context interactive-2019-09-10T08_41_53.263965.2019-09-10T08:41:55.852685 is 1.
# INFO:tensorflow:Processing input ./data.
# INFO:tensorflow:single_input Artifact(type_name: ExternalPath, uri: ./data, split: , id: 0).
# INFO:tensorflow:single_input.artifact uri: "./data"
# properties {
#   key: "split"
#   value {
#     string_value: ""
#   }
# }
# properties {
#   key: "type_name"
#   value {
#     string_value: "ExternalPath"
#   }
# }
# .
# INFO:tensorflow:Registered new input: id: 1
# type_id: 2
# uri: "./data"
# properties {
#   key: "split"
#   value {
#     string_value: ""
#   }
# }
# properties {
#   key: "state"
#   value {
#     string_value: "published"
#   }
# }
# properties {
#   key: "type_name"
#   value {
#     string_value: "ExternalPath"
#   }
# }
# custom_properties {
#   key: "input_fingerprint"
#   value {
#     string_value: "split:train,num_files:1,total_bytes:67847507,xor_checksum:1567502741,sum_checksum:1567502741\nsplit:eval,num_files:1,total_bytes:13573009,xor_checksum:1567502749,sum_checksum:1567502749"
#   }
# }
#
# WARNING:tensorflow:From /home/ummon/Documents/github.com/valeriano-manassero/tfx-kubeflow-pipelines/venv/lib/python3.6/site-packages/tfx/components/base/base_driver.py:44: The name tf.gfile.Exists is deprecated. Please use tf.io.gfile.exists instead.
#
# INFO:tensorflow:Resolved input artifacts are: {'input_base': [Artifact(type_name: ExternalPath, uri: ./data, split: , id: 1)]}
# INFO:tensorflow:Prepared EXECUTION:
#  type_id: 3
# properties {
#   key: "component_id"
#   value {
#     string_value: "ImportExampleGen"
#   }
# }
# properties {
#   key: "custom_config"
#   value {
#     string_value: "None"
#   }
# }
# properties {
#   key: "input_config"
#   value {
#     string_value: "{\n  \"splits\": [\n    {\n      \"name\": \"train\",\n      \"pattern\": \"train.tfrecord\"\n    },\n    {\n      \"name\": \"eval\",\n      \"pattern\": \"test.tfrecord\"\n    }\n  ]\n}"
#   }
# }
# properties {
#   key: "output_config"
#   value {
#     string_value: "{}"
#   }
# }
# properties {
#   key: "pipeline_name"
#   value {
#     string_value: "interactive-2019-09-10T08_41_53.263965"
#   }
# }
# properties {
#   key: "pipeline_root"
#   value {
#     string_value: "/tmp/tfx-interactive-2019-09-10T08_41_53.263965-6bkpvtgc"
#   }
# }
# properties {
#   key: "run_id"
#   value {
#     string_value: "2019-09-10T08:41:55.852685"
#   }
# }
# properties {
#   key: "state"
#   value {
#     string_value: "new"
#   }
# }
#
# INFO:tensorflow:Execution id of the upcoming component execution is 1
# INFO:tensorflow:Checking previous run for execution_type_name tfx.components.example_gen.import_example_gen.component.ImportExampleGen and input_artifacts {'input_base': [Artifact(type_name: ExternalPath, uri: ./data, split: , id: 1)]}
# INFO:tensorflow:Prepared EXECUTION:
#  type_id: 3
# properties {
#   key: "component_id"
#   value {
#     string_value: "ImportExampleGen"
#   }
# }
# properties {
#   key: "custom_config"
#   value {
#     string_value: "None"
#   }
# }
# properties {
#   key: "input_config"
#   value {
#     string_value: "{\n  \"splits\": [\n    {\n      \"name\": \"train\",\n      \"pattern\": \"train.tfrecord\"\n    },\n    {\n      \"name\": \"eval\",\n      \"pattern\": \"test.tfrecord\"\n    }\n  ]\n}"
#   }
# }
# properties {
#   key: "output_config"
#   value {
#     string_value: "{}"
#   }
# }
# properties {
#   key: "pipeline_name"
#   value {
#     string_value: "interactive-2019-09-10T08_41_53.263965"
#   }
# }
# properties {
#   key: "pipeline_root"
#   value {
#     string_value: "/tmp/tfx-interactive-2019-09-10T08_41_53.263965-6bkpvtgc"
#   }
# }
# properties {
#   key: "run_id"
#   value {
#     string_value: "2019-09-10T08:41:55.852685"
#   }
# }
# properties {
#   key: "state"
#   value {
#     string_value: "complete"
#   }
# }
#
# INFO:tensorflow:No execution matching type id and input artifacts found
# INFO:tensorflow:Cached results not found, move on to new execution
# INFO:tensorflow:Creating output artifact uri /tmp/tfx-interactive-2019-09-10T08_41_53.263965-6bkpvtgc/ImportExampleGen/examples/1/train/ as directory
# INFO:tensorflow:Creating output artifact uri /tmp/tfx-interactive-2019-09-10T08_41_53.263965-6bkpvtgc/ImportExampleGen/examples/1/eval/ as directory
# INFO:tensorflow:Output artifacts skeleton for the upcoming execution are: {'examples': [Artifact(type_name: ExamplesPath, uri: /tmp/tfx-interactive-2019-09-10T08_41_53.263965-6bkpvtgc/ImportExampleGen/examples/1/train/, split: train, id: 0), Artifact(type_name: ExamplesPath, uri: /tmp/tfx-interactive-2019-09-10T08_41_53.263965-6bkpvtgc/ImportExampleGen/examples/1/eval/, split: eval, id: 0)]}
# INFO:tensorflow:Execution properties for the upcoming execution are: {'input_config': '{\n  "splits": [\n    {\n      "name": "train",\n      "pattern": "train.tfrecord"\n    },\n    {\n      "name": "eval",\n      "pattern": "test.tfrecord"\n    }\n  ]\n}', 'output_config': '{}', 'custom_config': None}
# INFO:tensorflow:Run executor for ImportExampleGen
# INFO:tensorflow:Starting Executor execution.
# INFO:tensorflow:Inputs for Executor is: {"input_base": [{"artifact": {"id": "1", "typeId": "2", "uri": "./data", "properties": {"state": {"stringValue": "published"}, "type_name": {"stringValue": "ExternalPath"}, "split": {"stringValue": ""}}, "customProperties": {"input_fingerprint": {"stringValue": "split:train,num_files:1,total_bytes:67847507,xor_checksum:1567502741,sum_checksum:1567502741\nsplit:eval,num_files:1,total_bytes:13573009,xor_checksum:1567502749,sum_checksum:1567502749"}}}, "artifact_type": {"id": "2", "name": "ExternalPath", "properties": {"name": "STRING", "type_name": "STRING", "state": "STRING", "producer_component": "STRING", "span": "INT", "pipeline_name": "STRING", "split": "STRING"}}}]}
# INFO:tensorflow:Outputs for Executor is: {"examples": [{"artifact": {"uri": "/tmp/tfx-interactive-2019-09-10T08_41_53.263965-6bkpvtgc/ImportExampleGen/examples/1/train/", "properties": {"name": {"stringValue": "examples"}, "type_name": {"stringValue": "ExamplesPath"}, "split": {"stringValue": "train"}, "producer_component": {"stringValue": "ImportExampleGen"}, "pipeline_name": {"stringValue": "interactive-2019-09-10T08_41_53.263965"}}}, "artifact_type": {"name": "ExamplesPath", "properties": {"state": "STRING", "producer_component": "STRING", "span": "INT", "pipeline_name": "STRING", "split": "STRING", "name": "STRING", "type_name": "STRING"}}}, {"artifact": {"uri": "/tmp/tfx-interactive-2019-09-10T08_41_53.263965-6bkpvtgc/ImportExampleGen/examples/1/eval/", "properties": {"name": {"stringValue": "examples"}, "type_name": {"stringValue": "ExamplesPath"}, "split": {"stringValue": "eval"}, "producer_component": {"stringValue": "ImportExampleGen"}, "pipeline_name": {"stringValue": "interactive-2019-09-10T08_41_53.263965"}}}, "artifact_type": {"name": "ExamplesPath", "properties": {"split": "STRING", "name": "STRING", "type_name": "STRING", "state": "STRING", "producer_component": "STRING", "span": "INT", "pipeline_name": "STRING"}}}]}
# INFO:tensorflow:Execution properties for Executor is: {"input_config": "{\n  \"splits\": [\n    {\n      \"name\": \"train\",\n      \"pattern\": \"train.tfrecord\"\n    },\n    {\n      \"name\": \"eval\",\n      \"pattern\": \"test.tfrecord\"\n    }\n  ]\n}", "output_config": "{}", "custom_config": null}
# INFO:tensorflow:Generating examples.
# INFO:tensorflow:Reading input TFExample data ./data/train.tfrecord.
# INFO:tensorflow:Reading input TFExample data ./data/test.tfrecord.
# WARNING:root:Couldn't find python-snappy so the implementation of _TFRecordUtil._masked_crc32c is not as fast as it could be.
# INFO:tensorflow:Examples generated.
# INFO:tensorflow:Run publisher for ImportExampleGen
# INFO:tensorflow:Whether cached results are used: False
# INFO:tensorflow:Execution id: 1
# INFO:tensorflow:Inputs: {'input_base': [Artifact(type_name: ExternalPath, uri: ./data, split: , id: 1)]}
# INFO:tensorflow:Outputs: {'examples': [Artifact(type_name: ExamplesPath, uri: /tmp/tfx-interactive-2019-09-10T08_41_53.263965-6bkpvtgc/ImportExampleGen/examples/1/train/, split: train, id: 0), Artifact(type_name: ExamplesPath, uri: /tmp/tfx-interactive-2019-09-10T08_41_53.263965-6bkpvtgc/ImportExampleGen/examples/1/eval/, split: eval, id: 0)]}
# INFO:tensorflow:Publishing execution id: 1
# type_id: 3
# properties {
#   key: "component_id"
#   value {
#     string_value: "ImportExampleGen"
#   }
# }
# properties {
#   key: "custom_config"
#   value {
#     string_value: "None"
#   }
# }
# properties {
#   key: "input_config"
#   value {
#     string_value: "{\n  \"splits\": [\n    {\n      \"name\": \"train\",\n      \"pattern\": \"train.tfrecord\"\n    },\n    {\n      \"name\": \"eval\",\n      \"pattern\": \"test.tfrecord\"\n    }\n  ]\n}"
#   }
# }
# properties {
#   key: "output_config"
#   value {
#     string_value: "{}"
#   }
# }
# properties {
#   key: "pipeline_name"
#   value {
#     string_value: "interactive-2019-09-10T08_41_53.263965"
#   }
# }
# properties {
#   key: "pipeline_root"
#   value {
#     string_value: "/tmp/tfx-interactive-2019-09-10T08_41_53.263965-6bkpvtgc"
#   }
# }
# properties {
#   key: "run_id"
#   value {
#     string_value: "2019-09-10T08:41:55.852685"
#   }
# }
# properties {
#   key: "state"
#   value {
#     string_value: "complete"
#   }
# }
# , with inputs {'input_base': [Artifact(type_name: ExternalPath, uri: ./data, split: , id: 1)]} and outputs {'examples': [Artifact(type_name: ExamplesPath, uri: /tmp/tfx-interactive-2019-09-10T08_41_53.263965-6bkpvtgc/ImportExampleGen/examples/1/train/, split: train, id: 0), Artifact(type_name: ExamplesPath, uri: /tmp/tfx-interactive-2019-09-10T08_41_53.263965-6bkpvtgc/ImportExampleGen/examples/1/eval/, split: eval, id: 0)]}
# INFO:tensorflow:Published execution with final outputs {'examples': [Artifact(type_name: ExamplesPath, uri: /tmp/tfx-interactive-2019-09-10T08_41_53.263965-6bkpvtgc/ImportExampleGen/examples/1/train/, split: train, id: 2), Artifact(type_name: ExamplesPath, uri: /tmp/tfx-interactive-2019-09-10T08_41_53.263965-6bkpvtgc/ImportExampleGen/examples/1/eval/, split: eval, id: 3)]}
# ExecutionResult(
#     component_id: ImportExampleGen
#     execution_id: 1
#     outputs:
#         examples: Channel(
#             type_name: ExamplesPath
#             artifacts: [Artifact(type_name: ExamplesPath, uri: /tmp/tfx-interactive-2019-09-10T08_41_53.263965-6bkpvtgc/ImportExampleGen/examples/1/train/, split: train, id: 2)
#             Artifact(type_name: ExamplesPath, uri: /tmp/tfx-interactive-2019-09-10T08_41_53.263965-6bkpvtgc/ImportExampleGen/examples/1/eval/, split: eval, id: 3)]
#         ))

# %%
statistics_gen = StatisticsGen(input_data=example_gen.outputs['examples'])
 
context.run(statistics_gen)
# Out:
# W0903 20:22:09.978128 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:09.979510 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:09.980391 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:09.981054 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:09.981710 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:09.982313 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:09.982908 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:09.983626 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:09.984372 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:09.984981 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:09.985635 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:09.986235 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:09.988999 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:09.989382 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:09.989710 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:09.990027 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:09.990343 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:09.990657 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:09.990974 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:09.991300 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:09.991636 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:09.991957 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:09.992265 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:09.992574 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:09.992892 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:09.993244 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:09.993561 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:09.993872 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:09.994185 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:09.994492 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:09.994805 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:09.995126 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:09.995473 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:09.995813 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:09.996150 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:09.996478 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:09.996804 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:09.997137 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:09.997466 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:09.997791 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:09.998122 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:09.998450 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:09.998777 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:09.999104 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:09.999461 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:09.999805 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:10.000157 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:10.000509 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:10.000835 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:10.001184 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:10.001520 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:10.001862 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:10.002210 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:10.002552 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:10.002893 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:10.003239 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:10.003597 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:10.003948 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:10.004313 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:10.004665 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:10.005002 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:10.005382 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:10.005743 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:10.006088 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:10.006432 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:10.006775 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:10.007150 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:10.007518 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:10.007870 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:10.008216 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:10.008560 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:10.008898 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:10.009240 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:10.009587 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:10.009932 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:10.010272 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:10.010636 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:10.010981 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:10.011348 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:10.011719 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:10.012075 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:10.012448 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:10.012802 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:10.013150 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:10.013499 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:10.013852 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:10.014201 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:10.014545 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:10.014914 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:10.015977 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:10.016844 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:10.017684 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:10.018515 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:10.019474 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:10.020453 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:10.021350 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:10.022211 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:10.023067 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:10.023970 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:10.024816 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:10.025653 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:10.026466 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:10.027318 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:10.028176 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:10.028652 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:10.029134 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:10.029600 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:10.030055 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:10.030507 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:10.031036 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:10.031435 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:10.031812 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:10.032184 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:10.032603 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:10.032987 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:10.033522 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:10.033957 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:10.034392 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:10.034794 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:10.035201 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:10.035655 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:10.036051 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:10.036426 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:10.036802 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:10.037178 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:10.037545 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:10.037932 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:10.038304 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:10.040562 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:10.044126 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:10.044545 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:10.044948 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:10.045328 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:10.045719 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:10.046102 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:10.046474 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:10.046858 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:10.047274 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:10.047665 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:10.048050 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:10.048428 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:10.048806 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:10.049187 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:10.049568 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:10.049913 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:10.050262 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:10.050608 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:10.050960 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:10.051328 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:10.051690 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:10.052030 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:10.052397 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:10.052738 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:10.053090 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:10.053440 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:10.053801 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:10.054145 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:10.054504 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:10.054836 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:10.055179 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:10.055581 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:10.055947 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:10.056303 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:10.056665 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:10.057017 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:10.057385 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:10.057739 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:10.058105 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:10.058457 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:10.058832 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:10.059193 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:10.059587 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:10.059973 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:10.060352 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:10.060719 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:10.061112 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:10.061497 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:10.061873 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:10.062242 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:10.062620 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:10.062990 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:10.063389 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:10.063784 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:10.064172 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:10.064554 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:10.064955 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:10.065321 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:10.065693 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:10.066059 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:10.066424 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:10.066783 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:10.067146 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:10.067557 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:10.067928 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:10.079347 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:10.083197 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:10.086681 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:10.087359 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:10.087837 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:10.088259 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:10.088620 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:10.088968 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:10.089328 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:10.089713 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:10.090092 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:10.090474 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:10.090859 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:10.091228 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:10.091685 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:10.092073 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:10.092471 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:10.092859 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:10.093236 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:10.093616 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:10.093994 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:10.094347 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:10.094726 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:10.095109 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:10.095519 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:10.095892 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:10.096297 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:10.096659 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:10.097038 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:10.097419 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:10.097789 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:10.098244 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:10.099567 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:10.101627 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:10.102012 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:10.102375 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:10.102733 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:10.103091 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:10.103489 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:10.103847 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:10.104202 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:10.104555 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:10.104896 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:10.105230 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:10.105621 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:10.105971 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:10.106324 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:10.106671 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:10.107028 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:10.107407 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:10.107772 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:10.108122 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:10.108472 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:10.108816 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:10.109174 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:10.109521 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:10.109880 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:10.110233 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:10.110572 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:10.110918 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:10.111306 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:10.111707 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:10.112121 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:10.112543 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:10.112906 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:10.113259 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:10.113615 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:10.113968 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:10.114312 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:10.114668 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:10.115020 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:10.115397 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:10.115754 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:10.116112 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:10.116475 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:10.116820 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:10.117196 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:10.117552 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:10.117905 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:10.118258 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:10.118613 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:10.118964 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:10.119336 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:10.119728 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:10.120175 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:10.120532 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:10.120889 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:10.121278 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:10.121660 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:10.122019 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:10.122384 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:10.122745 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:10.123118 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:10.123538 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:10.123901 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:10.124268 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:10.124661 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:10.125030 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:10.125392 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:10.125770 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:10.126129 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:10.126482 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# ...
# W0903 20:22:15.644993 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:15.645456 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:15.645900 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:15.646373 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:15.646825 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:15.647325 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:15.647798 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:15.648279 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:15.648760 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:15.649252 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:15.649698 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:15.650226 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:15.650585 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:15.651062 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:15.651529 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:15.651980 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:15.652415 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:15.652929 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:15.653429 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:15.653844 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:15.654231 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:15.654615 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:15.655025 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:15.655451 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:15.655860 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:15.656248 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:15.656637 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:15.657047 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:15.657438 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:15.657852 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:15.658489 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:15.658892 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:15.659300 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:15.659705 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:15.660118 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:15.660499 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:15.660786 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:15.661080 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:15.661346 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:15.661617 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:15.661920 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:15.662196 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:15.662467 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:15.662746 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:15.663020 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:15.663312 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:15.663603 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:15.663875 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:15.664146 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:15.664423 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:15.664690 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:15.664961 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:15.665242 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:15.665517 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:15.665783 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:15.666073 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:15.666371 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:15.666656 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:15.666927 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:15.667216 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:15.667549 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:15.667850 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:15.668155 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:15.668452 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:15.668797 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:15.669107 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:15.669412 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:15.669717 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:15.670057 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:15.670357 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:15.670652 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:15.670960 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:15.671294 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:15.671626 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:15.671957 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:15.672270 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:15.672579 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:15.672888 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:15.673198 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:15.673516 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:15.673837 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:15.674154 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:15.674488 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:15.674844 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:15.675174 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:15.675523 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:15.675844 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:15.676151 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:15.676460 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:15.676779 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:15.677094 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:15.677397 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:15.677720 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:15.678016 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# W0903 20:22:15.678314 140191945226048 top_k_uniques_stats_generator.py:133] Feature "image_raw" has bytes value "None" which cannot be decoded as a UTF-8 string.
# ExecutionResult(
#     component_id: StatisticsGen
#     execution_id: 2
#     outputs:
#         output: Channel(
#             type_name: ExampleStatisticsPath
#             artifacts: [Artifact(type_name: ExampleStatisticsPath, uri: /tmp/tfx-interactive-2019-09-03T20_21_55.462505-u52yuvqc/StatisticsGen/output/2/train/, split: train, id: 4)
#             Artifact(type_name: ExampleStatisticsPath, uri: /tmp/tfx-interactive-2019-09-03T20_21_55.462505-u52yuvqc/StatisticsGen/output/2/eval/, split: eval, id: 5)]
#         ))

# %%
artifact_list = statistics_gen.outputs['output'].get()
train_artifact_uri = get_split_uri(artifact_list, 'train')
train_stats_path = os.path.join(train_artifact_uri, 'stats_tfrecord')
eval_artifact_uri = get_split_uri(artifact_list, 'eval')
eval_stats_path = os.path.join(eval_artifact_uri, 'stats_tfrecord')
# Out:
# W0903 20:22:17.283006 140191945226048 deprecation.py:323] From <ipython-input-9-b7b1d7d201be>:2: get_split_uri (from tfx.utils.types) is deprecated and will be removed in a future version.
# Instructions for updating:
# tfx.utils.types.get_split_uri has been renamed to tfx.types.artifact_utils.get_split_uri as of TFX 0.14.0.

# %%
train_stats = tfdv.load_statistics(train_stats_path)
eval_stats = tfdv.load_statistics(eval_stats_path)

tfdv.visualize_statistics(lhs_statistics=eval_stats, rhs_statistics=train_stats,
                          lhs_name='EVAL_DATASET', rhs_name='TRAIN_DATASET')
# Out:
# W0903 20:22:17.293728 140191945226048 deprecation.py:323] From /opt/interactive_pipeline/venv/lib/python3.6/site-packages/tensorflow_data_validation/utils/stats_gen_lib.py:357: tf_record_iterator (from tensorflow.python.lib.io.tf_record) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use eager execution and:
# `tf.data.TFRecordDataset(path)`
# <iframe id='facets-iframe' width="100%" height="500px"></iframe>
#         <script>
#         facets_iframe = document.getElementById('facets-iframe');
#         facets_html = '<link rel="import" href="https://raw.githubusercontent.com/PAIR-code/facets/master/facets-dist/facets-jupyter.html"><facets-overview proto-input="..."></facets-overview>';
#         facets_iframe.srcdoc = facets_html;
#          facets_iframe.id = "";
#          setTimeout(() => {
#            facets_iframe.setAttribute('height', facets_iframe.contentWindow.document.body.offsetHeight + 'px')
#          }, 1500)
#          </script>

# %%
infer_schema = SchemaGen(stats=statistics_gen.outputs['output'],
                         infer_feature_shape=True)

context.run(infer_schema)
# Out:
# W0903 20:22:17.358348 140191945226048 deprecation_wrapper.py:119] From /opt/interactive_pipeline/venv/lib/python3.6/site-packages/tfx/utils/io_utils.py:76: The name tf.gfile.ListDirectory is deprecated. Please use tf.io.gfile.listdir instead.
# ExecutionResult(
#     component_id: SchemaGen
#     execution_id: 3
#     outputs:
#         output: Channel(
#             type_name: SchemaPath
#             artifacts: [Artifact(type_name: SchemaPath, uri: /tmp/tfx-interactive-2019-09-03T20_21_55.462505-u52yuvqc/SchemaGen/output/3/, split: , id: 6)]
#         ))

# %%
schema_dir = infer_schema.outputs['output'].get()[0].uri
schema_path = os.path.join(schema_dir, 'schema.pbtxt')

schema = tfdv.load_schema_text(schema_path)
tfdv.display_schema(schema)
# Out:
#                Type  Presence Valency Domain
# Feature name
# 'image_raw'   BYTES  required  single      -
# 'label'         INT  required  single      -

# %%
validate_stats = ExampleValidator(stats=statistics_gen.outputs['output'],
                                  schema=infer_schema.outputs['output'])

context.run(validate_stats)
# Out:
# ExecutionResult(
#     component_id: ExampleValidator
#     execution_id: 4
#     outputs:
#         output: Channel(
#             type_name: ExampleValidationPath
#             artifacts: [Artifact(type_name: ExampleValidationPath, uri: /tmp/tfx-interactive-2019-09-03T20_21_55.462505-u52yuvqc/ExampleValidator/output/4/, split: , id: 7)]
#         ))

# %%
validation_dir = validate_stats.outputs['output'].get()[0].uri
anomalies_path = os.path.join(validation_dir, 'anomalies.pbtxt')

anomalies = tfdv.load_anomalies_text(anomalies_path)
tfdv.display_anomalies(anomalies)
# Out:
# <h4 style="color:green;">No anomalies found.</h4>

# %%
_module_file = os.path.join(_root, 'utils.py')

transform = Transform(
    input_data=example_gen.outputs['examples'],
    schema=infer_schema.outputs['output'],
    module_file=_module_file)

context.run(transform)
# Out:
# W0903 20:22:17.575049 140191945226048 deprecation_wrapper.py:119] From /opt/interactive_pipeline/venv/lib/python3.6/site-packages/tfx/components/transform/executor.py:241: The name tf.logging.debug is deprecated. Please use tf.compat.v1.logging.debug instead.
#
# W0903 20:22:17.576533 140191945226048 deprecation.py:323] From /opt/interactive_pipeline/venv/lib/python3.6/site-packages/tfx/components/transform/executor.py:406: Schema (from tensorflow_transform.tf_metadata.dataset_schema) is deprecated and will be removed in a future version.
# Instructions for updating:
# Schema is a deprecated, use schema_utils.schema_from_feature_spec to create a `Schema`
# W0903 20:22:18.066849 140191945226048 deprecation.py:323] From /opt/interactive_pipeline/venv/lib/python3.6/site-packages/tensorflow/python/saved_model/signature_def_utils_impl.py:201: build_tensor_info (from tensorflow.python.saved_model.utils_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This function will only be available through the v1 compatibility library as tf.compat.v1.saved_model.utils.build_tensor_info or tf.compat.v1.saved_model.build_tensor_info.
# W0903 20:24:16.717128 140191945226048 deprecation_wrapper.py:119] From /opt/interactive_pipeline/venv/lib/python3.6/site-packages/tfx/utils/io_utils.py:87: The name tf.gfile.IsDirectory is deprecated. Please use tf.io.gfile.isdir instead.
#
# W0903 20:24:16.719441 140191945226048 deprecation_wrapper.py:119] From /opt/interactive_pipeline/venv/lib/python3.6/site-packages/tfx/utils/io_utils.py:88: The name tf.gfile.DeleteRecursively is deprecated. Please use tf.io.gfile.rmtree instead.
# ExecutionResult(
#     component_id: Transform
#     execution_id: 5
#     outputs:
#         transform_output: Channel(
#             type_name: TransformPath
#             artifacts: [Artifact(type_name: TransformPath, uri: /tmp/tfx-interactive-2019-09-03T20_21_55.462505-u52yuvqc/Transform/transform_output/5/, split: , id: 8)]
#         )
#         transformed_examples: Channel(
#             type_name: ExamplesPath
#             artifacts: [Artifact(type_name: ExamplesPath, uri: /tmp/tfx-interactive-2019-09-03T20_21_55.462505-u52yuvqc/Transform/transformed_examples/5/train/, split: train, id: 9)
#             Artifact(type_name: ExamplesPath, uri: /tmp/tfx-interactive-2019-09-03T20_21_55.462505-u52yuvqc/Transform/transformed_examples/5/eval/, split: eval, id: 10)]
#         ))

# %%
trainer = Trainer(
    module_file=_module_file,
    examples=transform.outputs['transformed_examples'],
    schema=infer_schema.outputs['output'],
    transform_output=transform.outputs['transform_output'],
    train_args=trainer_pb2.TrainArgs(num_steps=100),
    eval_args=trainer_pb2.EvalArgs(num_steps=50))
context.run(trainer)
# Out:
# W0903 20:24:16.911602 140191945226048 estimator.py:1811] Using temporary folder as model directory: /tmp/tmpzb_4_e6q
# W0903 20:24:16.927376 140191945226048 deprecation.py:506] From /opt/interactive_pipeline/venv/lib/python3.6/site-packages/tensorflow/python/ops/init_ops.py:97: calling GlorotUniform.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# W0903 20:24:16.928214 140191945226048 deprecation.py:506] From /opt/interactive_pipeline/venv/lib/python3.6/site-packages/tensorflow/python/ops/init_ops.py:1251: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# W0903 20:24:16.928917 140191945226048 deprecation.py:506] From /opt/interactive_pipeline/venv/lib/python3.6/site-packages/tensorflow/python/ops/init_ops.py:97: calling Zeros.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# W0903 20:24:17.428559 140191945226048 deprecation.py:323] From /opt/interactive_pipeline/venv/lib/python3.6/site-packages/tensorflow/python/training/training_util.py:236: Variable.initialized_value (from tensorflow.python.ops.variables) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use Variable.read_value. Variables in 2.X are initialized automatically both in eager and graph (inside tf.defun) contexts.
# W0903 20:24:17.440372 140191945226048 deprecation.py:323] From /opt/interactive_pipeline/venv/lib/python3.6/site-packages/tensorflow/python/data/experimental/ops/readers.py:835: parallel_interleave (from tensorflow.python.data.experimental.ops.interleave_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.interleave(map_func, cycle_length, block_length, num_parallel_calls=tf.data.experimental.AUTOTUNE)` instead. If sloppy execution is desired, use `tf.data.Options.experimental_determinstic`.
# W0903 20:24:17.461111 140191945226048 deprecation.py:323] From /opt/interactive_pipeline/venv/lib/python3.6/site-packages/tensorflow/python/data/experimental/ops/readers.py:212: shuffle_and_repeat (from tensorflow.python.data.experimental.ops.shuffle_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.shuffle(buffer_size, seed)` followed by `tf.data.Dataset.repeat(count)`. Static tf.data optimizations will take care of using the fused implementation.
# W0903 20:24:17.470647 140191945226048 deprecation.py:323] From ./utils.py:65: DatasetV1.make_one_shot_iterator (from tensorflow.python.data.ops.dataset_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `for ... in dataset:` to iterate over a dataset. If using `tf.estimator`, return the `Dataset` object directly from your input function. As a last resort, you can use `tf.compat.v1.data.make_one_shot_iterator(dataset)`.
# W0903 20:24:17.693907 140191945226048 deprecation.py:323] From /opt/interactive_pipeline/venv/lib/python3.6/site-packages/tensorflow/python/ops/array_ops.py:1354: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# W0903 20:24:20.637286 140191945226048 deprecation.py:323] From /opt/interactive_pipeline/venv/lib/python3.6/site-packages/tensorflow/python/training/saver.py:1276: checkpoint_exists (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to check for files with this prefix.
# W0903 20:24:21.761544 140191945226048 deprecation_wrapper.py:119] From ./utils.py:74: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0903 20:24:21.763764 140191945226048 deprecation_wrapper.py:119] From ./utils.py:76: The name tf.parse_example is deprecated. Please use tf.io.parse_example instead.
#
# W0903 20:24:21.880709 140191945226048 export_utils.py:182] Export includes no default signature!
# ExecutionResult(
#     component_id: Trainer
#     execution_id: 6
#     outputs:
#         output: Channel(
#             type_name: ModelExportPath
#             artifacts: [Artifact(type_name: ModelExportPath, uri: /tmp/tfx-interactive-2019-09-03T20_21_55.462505-u52yuvqc/Trainer/output/6/, split: , id: 11)]
#         ))

# %%
OVERALL_SLICE_SPEC = evaluator_pb2.SingleSlicingSpec()

ALL_SPECS = [
    OVERALL_SLICE_SPEC,
]

# %%
model_analyzer = Evaluator(
    examples=example_gen.outputs['examples'],
    model_exports=trainer.outputs['output'],
    feature_slicing_spec=evaluator_pb2.FeatureSlicingSpec(
        specs=ALL_SPECS
    ))

context.run(model_analyzer)
# Out:
# W0903 20:24:22.610947 140191945226048 deprecation.py:323] From /opt/interactive_pipeline/venv/lib/python3.6/site-packages/tensorflow_model_analysis/eval_saved_model/load.py:163: load (from tensorflow.python.saved_model.loader_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This function will only be available through the v1 compatibility library as tf.compat.v1.saved_model.loader.load or tf.compat.v1.saved_model.load. There will be a new function for importing SavedModels in Tensorflow 2.0.
# W0903 20:24:22.704847 140191945226048 deprecation.py:323] From /opt/interactive_pipeline/venv/lib/python3.6/site-packages/tensorflow_model_analysis/eval_saved_model/graph_ref.py:189: get_tensor_from_tensor_info (from tensorflow.python.saved_model.utils_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This function will only be available through the v1 compatibility library as tf.compat.v1.saved_model.utils.get_tensor_from_tensor_info or tf.compat.v1.saved_model.get_tensor_from_tensor_info.
# ExecutionResult(
#     component_id: Evaluator
#     execution_id: 7
#     outputs:
#         output: Channel(
#             type_name: ModelEvalPath
#             artifacts: [Artifact(type_name: ModelEvalPath, uri: /tmp/tfx-interactive-2019-09-03T20_21_55.462505-u52yuvqc/Evaluator/output/7/, split: , id: 12)]
#         ))

# %%
PATH_TO_RESULT = model_analyzer.outputs['output'].get()[0].uri
tfma_result = tfma.load_eval_result(PATH_TO_RESULT)
tfma.view.render_slicing_metrics(tfma_result)
# Out:
# SlicingMetricsViewer(config={'weightedExamplesColumn': 'post_export_metrics/example_count'}, data=[{'slice': '…

# %%
model_validator = ModelValidator(
    examples=example_gen.outputs['examples'],
    model=trainer.outputs['output'])

context.run(model_validator)
# Out:
# ExecutionResult(
#     component_id: ModelValidator
#     execution_id: 8
#     outputs:
#         blessing: Channel(
#             type_name: ModelBlessingPath
#             artifacts: [Artifact(type_name: ModelBlessingPath, uri: /tmp/tfx-interactive-2019-09-03T20_21_55.462505-u52yuvqc/ModelValidator/blessing/8/, split: , id: 13)]
#         ))

# %%
pusher = Pusher(
    model_export=trainer.outputs['output'],
    model_blessing=model_validator.outputs['blessing'],
    push_destination=pusher_pb2.PushDestination(
        filesystem=pusher_pb2.PushDestination.Filesystem(
            base_directory=_serving_model_dir)))

context.run(pusher)
